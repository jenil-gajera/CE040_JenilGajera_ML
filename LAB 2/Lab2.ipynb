# %% [markdown]
# # 1) Missing Values

# %%
import numpy as np 
import pandas as pd
from sklearn.impute import SimpleImputer 
        
datasets = pd.read_csv('Exercise-CarData.csv') 
print("\nData :\n",datasets)
print("\nData statistics\n",datasets.describe())
# Out:
# Data :
#        Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
X = datasets.iloc[:, :-1].values  
Y = datasets.iloc[:, -1].values 

print("\n\nInput : \n", X) 
print("\n\nOutput: \n", Y)
# Out:
# Input :
#  [[0 13500 23.0 ... 0 2000 'three']
#  [1 13750 23.0 ... 0 2000 '3']
#  [2 13950 24.0 ... 0 2000 '3']
#  ...
#  [1433 8500 nan ... 0 1300 '3']
#  [1434 7250 70.0 ... 0 1300 '3']
#  [1435 6950 76.0 ... 0 1600 '5']]
#
#
# Output:
#  [1165 1165 1165 ... 1015 1015 1114]

# %%
datasets.dropna(axis=0,how='all',inplace=True)
print("\nNew Data :",datasets)
# Out:
# New Data :       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
updated_df = datasets;
updated_df['Age']=updated_df['Age'].fillna(updated_df['Age'].mean())
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1436 non-null   float64
#  3   KM          1436 non-null   object
#  4   FuelType    1336 non-null   object
#  5   HP          1436 non-null   object
#  6   MetColor    1286 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   object
#  10  Weight      1436 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 134.6+ KB

# %%
datasets
# Out:
#       Unnamed: 0  Price        Age     KM FuelType   HP  MetColor  Automatic  \
# 0              0  13500  23.000000  46986   Diesel   90       1.0          0
# 1              1  13750  23.000000  72937   Diesel   90       1.0          0
# 2              2  13950  24.000000  41711   Diesel   90       NaN          0
# 3              3  14950  26.000000  48000   Diesel   90       0.0          0
# 4              4  13750  30.000000  38500   Diesel   90       0.0          0
# ...          ...    ...        ...    ...      ...  ...       ...        ...
# 1431        1431   7500  55.672156  20544   Petrol   86       1.0          0
# 1432        1432  10845  72.000000     ??   Petrol   86       0.0          0
# 1433        1433   8500  55.672156  17016   Petrol   86       0.0          0
# 1434        1434   7250  70.000000     ??      NaN   86       1.0          0
# 1435        1435   6950  76.000000      1   Petrol  110       0.0          0
#
#         CC  Doors  Weight
# ...

# %%
updated_df = datasets;
updated_df['MetColor']=updated_df['MetColor'].fillna(updated_df['MetColor'].mean())
updated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1436 non-null   float64
#  3   KM          1436 non-null   object
#  4   FuelType    1336 non-null   object
#  5   HP          1436 non-null   object
#  6   MetColor    1436 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   object
#  10  Weight      1436 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 134.6+ KB

# %%
datasets
# Out:
#       Unnamed: 0  Price        Age     KM FuelType   HP  MetColor  Automatic  \
# 0              0  13500  23.000000  46986   Diesel   90  1.000000          0
# 1              1  13750  23.000000  72937   Diesel   90  1.000000          0
# 2              2  13950  24.000000  41711   Diesel   90  0.674961          0
# 3              3  14950  26.000000  48000   Diesel   90  0.000000          0
# 4              4  13750  30.000000  38500   Diesel   90  0.000000          0
# ...          ...    ...        ...    ...      ...  ...       ...        ...
# 1431        1431   7500  55.672156  20544   Petrol   86  1.000000          0
# 1432        1432  10845  72.000000     ??   Petrol   86  0.000000          0
# 1433        1433   8500  55.672156  17016   Petrol   86  0.000000          0
# 1434        1434   7250  70.000000     ??      NaN   86  1.000000          0
# 1435        1435   6950  76.000000      1   Petrol  110  0.000000          0
#
#         CC  Doors  Weight
# ...

# %%
X = datasets.iloc[:, :-1].values
Y = datasets.iloc[:, -1].values 

print("\n\nInput : \n", X) 
print("\n\nOutput: \n", Y)
# Out:
# Input :
#  [[0 13500 23.0 ... 0 2000 'three']
#  [1 13750 23.0 ... 0 2000 '3']
#  [2 13950 24.0 ... 0 2000 '3']
#  ...
#  [1433 8500 55.67215568862275 ... 0 1300 '3']
#  [1434 7250 70.0 ... 0 1300 '3']
#  [1435 6950 76.0 ... 0 1600 '5']]
#
#
# Output:
#  [1165 1165 1165 ... 1015 1015 1114]

# %%
datasets.dropna(axis=0,inplace=True,how="any")
datasets.info()
print(datasets)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1336 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1336 non-null   int64
#  1   Price       1336 non-null   int64
#  2   Age         1336 non-null   float64
#  3   KM          1336 non-null   object
#  4   FuelType    1336 non-null   object
#  5   HP          1336 non-null   object
#  6   MetColor    1336 non-null   float64
#  7   Automatic   1336 non-null   int64
#  8   CC          1336 non-null   int64
#  9   Doors       1336 non-null   object
#  10  Weight      1336 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 125.2+ KB
#       Unnamed: 0  Price        Age     KM FuelType   HP  MetColor  Automatic  \
# 0              0  13500  23.000000  46986   Diesel   90  1.000000          0
# 1              1  13750  23.000000  72937   Diesel   90  1.000000          0
# ...

# %% [markdown]
# # Data Transformation

# %%
X = datasets.iloc[:, :-1].values
Y = datasets.iloc[:, -1].values 

X_new = datasets.iloc[:,1:3].values
print("\n\nX for transformation : \n", X_new)
# Out:
# X for transformation :
#  [[13500.            23.        ]
#  [13750.            23.        ]
#  [13950.            24.        ]
#  ...
#  [10845.            72.        ]
#  [ 8500.            55.67215569]
#  [ 6950.            76.        ]]

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_new)
print("\n\nScaled X : \n", X_scaled)
# Out:
# Scaled X :
#  [[0.33983287 0.27848101]
#  [0.34911792 0.27848101]
#  [0.35654596 0.29113924]
#  ...
#  [0.24122563 0.89873418]
#  [0.15413185 0.6920526 ]
#  [0.09656453 0.94936709]]

# %%
std = StandardScaler()
X_std = std.fit_transform(X_new)
print("\n\nStandardized X : \n", X_std)
# Out:
# Standardized X :
#  [[ 0.78334337 -1.82645748]
#  [ 0.85325972 -1.82645748]
#  [ 0.9091928  -1.77068333]
#  ...
#  [ 0.04083177  0.90647549]
#  [-0.61498356 -0.00419602]
#  [-1.0484649   1.12957205]]

# %% [markdown]
# # Handling Categorial Data

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
newx=datasets.iloc[:,:-1].values
label=LabelEncoder()
print("real Data \n",newx)
datasets.iloc[:,4]=label.fit_transform(newx[:,4])
print("Encoder data \n",datasets)
print("\n",datasets.info())
# Out:
# real Data
#  [[0 13500 23.0 ... 0 2000 'three']
#  [1 13750 23.0 ... 0 2000 '3']
#  [2 13950 24.0 ... 0 2000 '3']
#  ...
#  [1432 10845 72.0 ... 0 1300 '3']
#  [1433 8500 55.67215568862275 ... 0 1300 '3']
#  [1435 6950 76.0 ... 0 1600 '5']]
# Encoder data
#        Unnamed: 0  Price        Age     KM  FuelType   HP  MetColor  Automatic  \
# 0              0  13500  23.000000  46986         1   90  1.000000          0
# 1              1  13750  23.000000  72937         1   90  1.000000          0
# 2              2  13950  24.000000  41711         1   90  0.674961          0
# 3              3  14950  26.000000  48000         1   90  0.000000          0
# 4              4  13750  30.000000  38500         1   90  0.000000          0
# ...          ...    ...        ...    ...       ...  ...       ...        ...
# 1430        1430   8450  80.000000  23000         2   86  0.000000          0
# 1431        1431   7500  55.672156  20544         2   86  1.000000          0
# ...

# %%
temp_data=datasets
dummy = pd.get_dummies(temp_data['FuelType'])
print("\n\nDummy :\n",dummy)
temp_data = temp_data.drop(['FuelType','Weight'],axis=1)
temp_data = pd.concat([temp_data,dummy],axis=1)
print("\n\FuelType Data :\n",temp_data)
# Out:
# Dummy :
#        0  1  2
# 0     0  1  0
# 1     0  1  0
# 2     0  1  0
# 3     0  1  0
# 4     0  1  0
# ...  .. .. ..
# 1430  0  0  1
# 1431  0  0  1
# 1432  0  0  1
# 1433  0  0  1
# 1435  0  0  1
#
# [1336 rows x 3 columns]
#
# \FuelType Data :
#        Unnamed: 0  Price        Age     KM   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.000000  46986   90  1.000000          0  2000
# 1              1  13750  23.000000  72937   90  1.000000          0  2000
# 2              2  13950  24.000000  41711   90  0.674961          0  2000
# 3              3  14950  26.000000  48000   90  0.000000          0  2000
# 4              4  13750  30.000000  38500   90  0.000000          0  2000
# ...          ...    ...        ...    ...  ...       ...        ...   ...
# 1430        1430   8450  80.000000  23000   86  0.000000          0  1300
# 1431        1431   7500  55.672156  20544   86  1.000000          0  1300
# ...

# %%
onehotencoder = OneHotEncoder()
x = onehotencoder.fit_transform(datasets.FuelType.values.reshape(-1,1)).toarray()

dfOneHot = pd.DataFrame(x, columns = ["FuelType_"+str(int(i)) for i in range(3)]) 
df = pd.concat([datasets, dfOneHot], axis=1) 
df= df.drop(['FuelType'], axis=1) 
print(df.head())
# Out:
#    Unnamed: 0    Price   Age     KM  HP  MetColor  Automatic      CC  Doors  \
# 0         0.0  13500.0  23.0  46986  90  1.000000        0.0  2000.0  three
# 1         1.0  13750.0  23.0  72937  90  1.000000        0.0  2000.0      3
# 2         2.0  13950.0  24.0  41711  90  0.674961        0.0  2000.0      3
# 3         3.0  14950.0  26.0  48000  90  0.000000        0.0  2000.0      3
# 4         4.0  13750.0  30.0  38500  90  0.000000        0.0  2000.0      3
#
#    Weight  FuelType_0  FuelType_1  FuelType_2
# 0  1165.0         0.0         1.0         0.0
# 1  1165.0         0.0         1.0         0.0
# 2  1165.0         0.0         1.0         0.0
# 3  1165.0         0.0         1.0         0.0
# 4  1170.0         0.0         1.0         0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1427 entries, 0 to 1435
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1336 non-null   float64
#  1   Price       1336 non-null   float64
#  2   Age         1336 non-null   float64
#  3   KM          1336 non-null   object
#  4   HP          1336 non-null   object
#  5   MetColor    1336 non-null   float64
#  6   Automatic   1336 non-null   float64
#  7   CC          1336 non-null   float64
#  8   Doors       1336 non-null   object
#  9   Weight      1336 non-null   float64
#  10  FuelType_0  1336 non-null   float64
#  11  FuelType_1  1336 non-null   float64
#  12  FuelType_2  1336 non-null   float64
# dtypes: float64(10), object(3)
# memory usage: 156.1+ KB

# %% [markdown]
# # Feature Selaction and correction

# %%
import seaborn as sns
datasets.head()
# Out:
#    Unnamed: 0  Price   Age     KM  FuelType  HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986         1  90  1.000000          0  2000
# 1           1  13750  23.0  72937         1  90  1.000000          0  2000
# 2           2  13950  24.0  41711         1  90  0.674961          0  2000
# 3           3  14950  26.0  48000         1  90  0.000000          0  2000
# 4           4  13750  30.0  38500         1  90  0.000000          0  2000
#
#    Doors  Weight
# 0  three    1165
# 1      3    1165
# 2      3    1165
# 3      3    1165
# 4      3    1170

# %%
newx = datasets.iloc[:,:-1]
newx.head()
# Out:
#    Unnamed: 0  Price   Age     KM  FuelType  HP  MetColor  Automatic    CC
# 0           0  13500  23.0  46986         1  90  1.000000          0  2000
# 1           1  13750  23.0  72937         1  90  1.000000          0  2000
# 2           2  13950  24.0  41711         1  90  0.674961          0  2000
# 3           3  14950  26.0  48000         1  90  0.000000          0  2000
# 4           4  13750  30.0  38500         1  90  0.000000          0  2000

# %%
datasets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1336 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1336 non-null   int64
#  1   Price       1336 non-null   int64
#  2   Age         1336 non-null   float64
#  3   KM          1336 non-null   object
#  4   FuelType    1336 non-null   int32
#  5   HP          1336 non-null   object
#  6   MetColor    1336 non-null   float64
#  7   Automatic   1336 non-null   int64
#  8   CC          1336 non-null   int64
#  9   Doors       1336 non-null   object
# dtypes: float64(2), int32(1), int64(4), object(3)
# memory usage: 149.6+ KB

# %%
corr = newx.corr()
corr.head()
# Out:
#             Unnamed: 0     Price       Age  FuelType  MetColor  Automatic  \
# Unnamed: 0    1.000000 -0.737817  0.873736  0.149157 -0.086281   0.063540
# Price        -0.737817  1.000000 -0.856291  0.003437  0.121372   0.039874
# Age           0.873736 -0.856291  1.000000  0.057677 -0.099351   0.030335
# FuelType      0.149157  0.003437  0.057677  1.000000  0.008008   0.084989
# MetColor     -0.086281  0.121372 -0.099351  0.008008  1.000000  -0.012257
#
#                   CC
# Unnamed: 0 -0.171780
# Price       0.137370
# Age        -0.103787
# FuelType   -0.651491
# MetColor    0.027788

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= 0.9:
            if columns[j]:
                columns[j] = False

# %%
selected_columns = newx.columns[columns+2]
selected_columns.shape
# Out:
# (7,)

# %%
data = datasets[selected_columns]
print(data)
# Out:
#          KM     KM     KM     KM     KM     KM     KM
# 0     46986  46986  46986  46986  46986  46986  46986
# 1     72937  72937  72937  72937  72937  72937  72937
# 2     41711  41711  41711  41711  41711  41711  41711
# 3     48000  48000  48000  48000  48000  48000  48000
# 4     38500  38500  38500  38500  38500  38500  38500
# ...     ...    ...    ...    ...    ...    ...    ...
# 1430  23000  23000  23000  23000  23000  23000  23000
# 1431  20544  20544  20544  20544  20544  20544  20544
# 1432     ??     ??     ??     ??     ??     ??     ??
# 1433  17016  17016  17016  17016  17016  17016  17016
# 1435      1      1      1      1      1      1      1
#
# [1336 rows x 7 columns]
